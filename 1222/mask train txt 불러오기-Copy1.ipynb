# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import glob
import os

# %%
a = open("000_1ov3n5_0_jpeg.rf.edad89426b118f4c76ba4ae3790b3f31.txt","r")
a.read()
# Out:
# '0 0.4669354838709677 0.23925501432664756 0.18225806451612903 0.3123209169054441'

# %%
# import glob 
# files = glob.glob('*.txt')
# for file in files:
#     with open(file, 'r') as f:
#         f.read()

# %%
# import os
# for root, subdirs, files in os.walk("C:/Users/seok2/OneDrive/바탕 화면/Mask Wearing.v4-raw.darknet/train"):
# for file in files:
#     with open(file, 'r') as f:
#         f.read()

# %%
# import glob
# for filename in glob.glob('*.jpg'):
#     print(filename)

# %%
# import glob
# import os

# for filename in glob.glob('train/*.txt'):
#     with open(os.path.join(os.getcwd(), filename), 'r') as f:
#         text = f.read()
#         print(text)
        
#    with open(os.path.join(os.getcwd(), filename), 'r') as f:
#        text = f.read()
#        print(text)

# %%
# import glob

# targetPattern = r"C://train.txt"
# glob.glob(targetPattern)

# %%
os.path.isdir('C:/Users/seok2/OneDrive/바탕 화면/Mask Wearing.v4-raw.darknet/train')
# Out:
# True

# %%
for filename in glob.glob('C:/Users/seok2/OneDrive/바탕 화면/Mask Wearing.v4-raw.darknet/train/*.txt'):
    with open(os.path.join(os.getcwd(), filename), 'r') as f:
        text = f.read()
        print(text)
# Out:
# 0 0.0515 0.025678650036683785 0.071 0.049889948642699924
# 1 0.31825 0.04658840792369773 0.0735 0.09024211298606016
# 1 0.41975 0.05355832721936904 0.0655 0.09977989728539985
# 1 0.58 0.18121790168745414 0.078 0.14526779163609685
# 1 0.54075 0.23404255319148937 0.0905 0.16874541452677916
# 0 0.925 0.3132795304475422 0.093 0.1672780630961115
# 0 0.814 0.17571533382245047 0.082 0.1474688187820983
# 0 0.77425 0.4416727806309611 0.1065 0.18195157740278797
# 0 0.673 0.12032281731474688 0.088 0.16434336023477622
# 0 0.128 0.6544387380777696 0.25 0.4314013206162876
# 0 0.26075 0.14820249449743214 0.0935 0.16287600880410857
# 0 0.34575 0.1504035216434336 0.0955 0.19515774027879676
# 0 0.48525 0.3991195891415994 0.1045 0.20689655172413793
# 0 0.25677083333333334 0.21260767423649177 0.15416666666666667 0.22944400939702428
# 1 0.8419270833333333 0.5857478465152701 0.05260416666666667 0.07987470634299139
# 0 0.54609375 0.15270164447924825 0.1515625 0.23805794831636648
# ...
